# %% [markdown]
# # The Battle of Neighborhoods.

# %% [markdown]
# ### "Entering international palates"

# %% [markdown]
# ### 1. Introduction

# %% [markdown]
# A restaurant chain wants to enter new markets, based on its history, the restaurant chain has been in the local market for 20 years and has around 150 franchises distributed throughout the local territory, mainly in major cities. As part of the internalization strategy, investors want to assess the risks and their chances of success in this new adventure.
# As such, investors hire the services of a marketing consulting firm to respond to their requirements (risk assessment, probability of success, product acceptance in the market, among others). As part of the restaurant chain's requirement, they want to reach the US market first in one of its most important cities, New York, mainly in Manhattan.
# From the consultant's perspective, part of the requested research requires knowing the main neighborhoods to conduct the requested market study, this work is the first phase of the research "Entering international palates".

# %% [markdown]
# ### Business Problem

# %% [markdown]
# Manhattan is an island located at the mouth of the Hudson River in northern New York Harbor and is also one of five districts that are part of New York City, United States.
#
# 90% of New York's attractions are concentrated in Manhattan. In this area you will find the incomparable Empire State Bulding, the Rockefeller Center complex, the amazing Chrysler Building, the fascinating Times Square, the controversial MoMA and many other essential visits.
#
# The consultant does not know the different types of business and the destruction of these in the different neighborhoods of the city to develop studies of competition and business at the end, therefore, the following initial question is developed to have a starting point and use efficiently the resources directed to certain segments.

# %% [markdown]
# **Problem.** How are the different types of businesses distributed in the city's neighborhoods to guide market research on the most important ones based on the distribution of places or commercial businesses?

# %% [markdown]
# **Stakeholders of the Project.** The stakeholders of the project are:
# - The investors of the restaurant chain, the objective of these is profitability.
# - The collaborators that belong to the project, the objective of these is the success of the project.

# %% [markdown]
# ### 2. Data

# %% [markdown]
# Under the following premises, we have that as part of the initial stage of the marketing project, the different shops or businesses within 500 meters will be considered, as this gives the district some attractiveness compared to others.
#
# Based on the defined problem, we identified the following data sources:
#
# - The commercial businesses of the different Manhattan neighborhoods will be obtained from the Foursquare API: https://es.foursquare.com/
#
# - As part of obtaining the data mentioned above, we have to obtain the coordinates of the neighborhoods for them we will use the following source: https://geo.nyu.edu/catalog/nyu_2451_34572

# %% [markdown]
# ### 3. Methodology

# %% [markdown]
# The study case was developed based on the Data Science methodology, following the phases shown in the following image.

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DS0103EN/labs/images/lab1_fig1_flowchart_business_understanding.png" width=500>

# %% [markdown]
# 7 phases were developed for the practical case, from business understanding to modeling. The following describes how each of the phases was carried out for the development of the study case.
# - **Business Understanding:** As mentioned in the first part of the report, the Restaurant chain is carrying out its internalization strategy, therefore, it has contracted the services of the marketing consultant to identify potential markets, this led to the following question by from the consultant: How are the different types of businesses distributed in the city's neighborhoods to guide market research on the most important ones based on the distribution of places or commercial businesses?
# - **Analityc Approach:** To answer the question, the machine leaning approach was established with the K means algorithm
# - **Data Requeriments, Collections, Understading and Preparation:** The data requirements were to obtain data from the Manhattan district mainly: Neighborhoods, categories of venues (fast food, restaurants, culture, entertainment, etc.) with their respective latitude and longitude coordinates. Based on this, 2 dataset were identified for our case study: a New Yorok geojson file to obtain the coordinates of the different neighborhoods and information about the venues around the neighborhoods from the Foursquare API. The data was collected and explored to identify and correct cases of formats, missing values, among others. Finally, the preparation of the data resulted in a dataset that contained each neighborhood with the average of the number of venues around them.
# - **Modeling:** For the data modeling, the K means algorithm was established and an initial number of 5 clusters was defined.

# %% [markdown]
# ### 4. Results

# %% [markdown]
# The results of the modeling gave the following clusters:

# %% [markdown]
# #### Cluster 1

# %%
import pandas as pd
cluster1 = pd.read_csv('cluster1.csv')
cluster1
# Out:
#    Unnamed: 0   Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0          33  Midtown South     Korean Restaurant                 Hotel
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0   Japanese Restaurant          Dessert Shop          Burger Joint
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0  Gym / Fitness Center        Clothing Store                   Bar
#
#   9th Most Common Venue 10th Most Common Venue
# 0   American Restaurant            Coffee Shop

# %% [markdown]
# #### Cluster 2

# %%
cluster2 = pd.read_csv('cluster2.csv')
cluster2
# Out:
#    Unnamed: 0         Neighborhood 1st Most Common Venue  \
# 0           0          Marble Hill        Sandwich Place
# 1          11     Roosevelt Island                  Park
# 2          15              Midtown           Coffee Shop
# 3          16          Murray Hill        Sandwich Place
# 4          26  Morningside Heights                  Park
# 5          28    Battery Park City                  Park
# 6          29   Financial District           Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0           Coffee Shop                   Gym        Ice Cream Shop
# 1           Pizza Place        Sandwich Place  Gym / Fitness Center
# 2                 Hotel   Sporting Goods Shop        Clothing Store
# 3                 Hotel           Coffee Shop      Sushi Restaurant
# 4             Bookstore   American Restaurant           Coffee Shop
# 5                 Hotel                   Gym           Coffee Shop
# ...

# %% [markdown]
# #### Cluster 3

# %%
cluster3 = pd.read_csv('cluster3.csv')
cluster3
# Out:
#     Unnamed: 0       Neighborhood 1st Most Common Venue  \
# 0            5     Manhattanville           Coffee Shop
# 1            8    Upper East Side    Italian Restaurant
# 2            9          Yorkville    Italian Restaurant
# 3           10         Lenox Hill    Italian Restaurant
# 4           12    Upper West Side    Italian Restaurant
# 5           13     Lincoln Square                 Plaza
# 6           14            Clinton               Theater
# 7           17            Chelsea           Coffee Shop
# 8           18  Greenwich Village    Italian Restaurant
# 9           19       East Village                   Bar
# 10          21            Tribeca                  Park
# 11          23               Soho           Coffee Shop
# 12          24       West Village    Italian Restaurant
# 13          25   Manhattan Valley           Coffee Shop
# 14          27           Gramercy                   Bar
# 15          30      Carnegie Hill           Coffee Shop
# ...

# %% [markdown]
# #### Cluster 4

# %%
cluster4 = pd.read_csv('cluster4.csv')
cluster4
# Out:
#    Unnamed: 0        Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0           1           Chinatown    Chinese Restaurant          Cocktail Bar
# 1           2  Washington Heights                  Café                Bakery
# 2           3              Inwood    Mexican Restaurant           Pizza Place
# 3           4    Hamilton Heights           Pizza Place                  Café
# 4           6      Central Harlem  Gym / Fitness Center     French Restaurant
# 5           7         East Harlem    Mexican Restaurant                Bakery
# 6          20     Lower East Side    Chinese Restaurant           Art Gallery
# 7          22        Little Italy                Bakery                  Café
# 8          36          Tudor City                  Park                  Café
#
#   3rd Most Common Venue      4th Most Common Venue     5th Most Common Venue  \
# 0   American Restaurant                     Bakery                       Spa
# ...

# %% [markdown]
# #### Cluster 5

# %%
cluster5 = pd.read_csv('cluster5.csv')
cluster5
# Out:
#    Unnamed: 0     Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0          37  Stuyvesant Town         Boat or Ferry                  Park
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0                   Bar           Pet Service     German Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0        Baseball Field              Fountain       Harbor / Marina
#
#   9th Most Common Venue 10th Most Common Venue
# 0          Cocktail Bar            Coffee Shop

# %% [markdown]
# Let's visualize the clusters

# %%
from geopy.geocoders import Nominatim
import folium 
import numpy as np
import matplotlib.cm as cm 
import matplotlib.colors as colors

mapManhattan = pd.read_csv('mapManhattan.csv')

address = 'Manhattan, NY'
geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Manhattan are {}, {}.'.format(latitude, longitude))

# create map
kclusters = 5
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(mapManhattan['Latitude'], mapManhattan['Longitude'], mapManhattan['Neighborhood'], mapManhattan['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# The geograpical coordinate of Manhattan are 40.7896239, -73.9598939.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 5. Discussion

# %% [markdown]
# - In relation to the results presented by the 5 clusters associated with its particular development of shops and places at the end, we observed Clusters 3 as the most representative of the Manhattan district. Just looking at Cluster 3, there are 80% of restaurants, manifesting the large number of competitors in the Cluster neighborhoods.
# - On the other hand, observing Clusters 2 and 4 as we observe that the percentage is less than 40% but it is complemented by fast food places and coffee.

# %% [markdown]
# ### 6. Conclusion

# %% [markdown]
# - Getting to know which neighborhoods are more attractive based on the different commercial and cultural places, among others, provides us with a perspective focused on the services that are developed in the neighborhood and being a starting point to guide marketing efforts in the environment.
#
# - In addition, according to the results of the data modeling, it has oriented us to direct the efforts of searching and deepening the analysis in those neighborhoods with similarities and that may have a greater social-economic impact in the Manhattan district (Cluster 3).
#
# - Finally, this first approximation of neighborhoods does not give the opportunity to make a segmentation of neighborhoods based on other aspects, such as food places and associated market shares.
